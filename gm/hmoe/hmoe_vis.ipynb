# %%
import sys
sys.path.append("D:/proj/gross_machine")

from gm.hmoe.hmoe_nlp import get_test_scenario
from gm.hmoe.hmoe_cytoscape import CytoscapeHMoEVisualizer

# %%
model, scenario = get_test_scenario()
visualizer = CytoscapeHMoEVisualizer(model, scenario, 101, 4)
